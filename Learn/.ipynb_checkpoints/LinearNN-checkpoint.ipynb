# %% [markdown]
# ## 线性回归从0实现

# %%
# linear reality
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

# %%
# create a dataset
def synthetic_data(w,b,num_examples):
    X = torch.normal(0,1,(num_examples,len(w)))
    y = torch.matmul(X,w)+b
    y += torch.normal(0,0.01,y.shape)
    return X,y.reshape(-1,1)
true_w = torch.tensor([2,-3.4])
true_b = 4.2
features,labels = synthetic_data(true_w,true_b,1000)
#normal返回tensor,matmul返回张量积

# %%
# feature中每一行都包含一个二维数据样本，labels照片能够每行都包含一个标量
print('feature: ',features[0],"\nlabel: ",labels[0])
# Out:
# feature:  tensor([0.1786, 0.0465])
# label:  tensor([4.3828])

# %%
d2l.set_figsize()
d2l.plt.scatter(feature[:,1].detach().numpy(),labels.detach().numpy(),1);

# %%
# define a data_iter function
def data_iter(batch_size,features,labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    random.shuffle(indices)
    for i in range(0,num_examples,batch_size):
        batch_indices = torch.tensor(indices[i:min(i+batch_size,num_examples)])
        yield features[batch_indices], labels[batch_indices]
batch_size = 10
for X,y in data_iter(batch_size,features,labels):
    print (X,'\n',y)
    break
# Out:
# tensor([[ 1.0817, -0.0150],
#         [-2.0279, -0.8232],
#         [ 0.5588, -0.6119],
#         [-2.8897,  0.7426],
#         [ 1.6876,  0.4304],
#         [-0.8023,  0.8252],
#         [-1.3749,  0.0076],
#         [ 1.4779, -2.2179],
#         [-1.2996, -0.4445],
#         [ 0.6834,  0.0211]])
#  tensor([[ 6.4201],
#         [ 2.9393],
#         [ 7.4190],
#         [-4.0841],
#         [ 6.1130],
#         [-0.2135],
#         [ 1.4411],
#         [14.6974],
#         [ 3.1186],
#         [ 5.4999]])

# %%
# define initialize model parameter
w = torch.normal(0,0.01,size=(2,1),requires_grad=True)
b = torch.zeros(1,requires_grad=True)

# %%
# define model
def linereg(X,w,b):
    return torch.matmul(X,w)+b

# %%
# define loss function
def squared_loss(y_hat,y):
    return (y_hat-y.reshape(y_hat.shape))**2/2

# %%
#define optimization algorithm
def sgd(params,lr,batch_size):
    with torch.no_grad():
        for param in params:
            param -= lr*param.grad/batch_size
            param.grad.zero_

# %%
# train
lr = 0.03
num_epochs = 3
net = linereg
loss = squared_loss

for epoch in range(num_epochs):
    for X, y in data_iter(batch_size, features, labels):
        l = loss(net(X, w, b), y)
        l.sum().backward()
        sgd([w, b], lr, batch_size)
    with torch.no_grad():
        train_l = loss(net(features, w, b), labels)
        print(f'epoch {epoch + 1}, loss {float(train_l.mean()):f}')
# Out:
# epoch 1, loss 0.037129
# epoch 2, loss 0.000131
# epoch 3, loss 0.000049

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([0.0006, 0.0003], grad_fn=<SubBackward0>)
# b的估计误差: tensor([-0.0002], grad_fn=<RsubBackward1>)

# %% [markdown]
# ## 线性回归简单实现

# %%
# linear simple realize
import numpy as np
import torch
from torch.utils import data
from d2l import torch as d2l

true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = d2l.synthetic_data(true_w, true_b, 1000)

# %%
# use API to read data
def load_array(data_arrays, batch_size, is_train=True):  
    """构造一个PyTorch数据迭代器。"""
    dataset = data.TensorDataset(*data_arrays)
    return data.DataLoader(dataset, batch_size, shuffle=is_train)

batch_size = 10
data_iter = load_array((features, labels), batch_size)

next(iter(data_iter))
# Out:
# [tensor([[-1.4911, -0.4784],
#          [-1.4468,  0.3397],
#          [ 0.1969, -1.2963],
#          [ 1.0840, -0.7436],
#          [-1.2360, -1.8259],
#          [-0.2606, -0.2318],
#          [-0.4166,  0.2919],
#          [-0.8135,  1.1117],
#          [ 0.0980, -0.4525],
#          [ 0.4688, -1.7599]]),
#  tensor([[ 2.8390],
#          [ 0.1595],
#          [ 9.0009],
#          [ 8.8930],
#          [ 7.9173],
#          [ 4.4634],
#          [ 2.3798],
#          [-1.2070],
#          [ 5.9301],
#          [11.1340]])]

# %%
from torch import nn
net = nn.Sequential(nn.Linear(2,1))

# %%
# 初始化
net[0].weight.data.normal_(0,0.01)
net[0].bias.data.fill_(0)
# Out:
# tensor([0.])

# %%
# calculate loss
loss = nn.MSELoss()

# %%
# 实例化SGD实例
trainer = torch.optim.SGD(net.parameters(),lr=0.03)

# %%
num_epochs = 3
for epoch in range(num_epochs):
    for X,y in data_iter:
        l = loss(net(X),y)
        trainer.zero_grad()
        l.backward()
        trainer.step()
    l = loss(net(features),labels)
    print(f'epoch{epoch+1},loss{l:f}')
# Out:
# epoch1,loss0.000101
# epoch2,loss0.000100
# epoch3,loss0.000101
